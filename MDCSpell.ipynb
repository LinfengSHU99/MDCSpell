# %% [markdown]
# # 本文内容

# %% [markdown]
# 本文为MDCSpell: A Multi-task Detector-Corrector Framework for Chinese Spelling Correction论文的Pytorch实现。
#
# [论文地址](https://aclanthology.org/2022.findings-acl.98/): https://aclanthology.org/2022.findings-acl.98/
#
# 论文年份：2022
#
# [论文笔记](https://blog.csdn.net/zhaohongfei_358/article/details/126973451)：https://blog.csdn.net/zhaohongfei_358/article/details/126973451
#
# 论文大致内容：作者基于Transformer和BERT设计了一个多任务的网络来进行CSC（Chinese Spell Checking）任务（中文拼写纠错）。多任务分别是找出哪个字是错的和对错字进行纠正。
#
# 由于作者并没有公开代码，所以我就尝试自己实现一个，最终我的实验结果如下表：
#
# | Dataset | Model | D_Precision | D_Recall | D_F1 | C_Prec | C_Rec | C_F1 |
# |--|--|--|--|--|--|--|--|
# | SIGHAN 13 | MDCSpell | 89.1 | 78.3| 83.4 | 87.5| 76.8 | 81.8 |
# | SIGHAN 13 | MDCSpell(复现) | 80.2 | 79.9| 80.0 | 77.2| 76.9 | 77.1 |
# | SIGHAN 14 | MDCSpell | 70.2 | 68.8| 69.5 | 69.0| 67.7 | 68.3 |
# | SIGHAN 14 | MDCSpell(复现) | 82.8 | 66.6| 73.8 | 79.9| 64.3 | 71.2 |
# | SIGHAN 15 | MDCSpell | 80.8 | 80.6| 80.7 | 78.4| 78.2 | 78.3 |
# | SIGHAN 15 | MDCSpell(复现) | 86.7 | 76.1| 81.1 | 72.5| 82.7 | 77.3 |
#
# 这里是我训练了2个epoch的结果，与作者的结论相差不大。如果我增加训练次数的话，也许可以和作者的结果达到一致。

# %% [markdown]
# # 环境配置

# %%
try:
    import transformers
except:
    # !pip install transformers

# %%
import os
import copy
import pickle

import torch
import transformers

from torch import nn
from torch.utils.data import Dataset, DataLoader
from transformers import AutoModel, AutoTokenizer
from tqdm import tqdm

# %%
torch.__version__
# Out:
# '1.12.1+rocm5.1.1'

# %%
transformers.__version__
# Out:
# '4.21.2'

# %% [markdown]
# # 全局变量

# %%
# 句子的长度，作者并没有说明。我这里就按经验取一个
max_length = 128
# 作者使用的batch_size
batch_size = 32
# epoch数，作者并没有具体说明，按经验取一个
epochs = 10

# 每${log_after_step}步，打印一次日志
log_after_step = 20

# 模型存放的位置。
model_path = './drive/MyDrive/models/MDCSpell/'
os.makedirs(model_path, exist_ok=True)
model_path = model_path + 'MDCSpell-model.pt'

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print("Device:", device)
# Out:
# Device: cuda

# %% [markdown]
# # 模型构建

# %% [markdown]
# <img src="asserts/images/model.png">

# %% [markdown]
# ---
#
# **Correction Network** 的数据流向如下：
#
# 1.将token序列 `[CLS] 遇 到 逆 竟 [SEP]` 送给Word Embedding模块进行embeddings，得到向量$\{e_{CLS}^w, e_1^w, e_2^w, e_3^w, e_4^w,e_{SEP}^w\}$。
#
# > 个人认为此时的embedding仅仅是Word Embeding，并不包含Position Embedding和Segment Embedding。
#
# 2.之后将$\{e_{CLS}^w, e_1^w, e_2^w, e_3^w, e_4^w,e_{SEP}^w\}$向量送入BERT，增加Position Embedding和Segment Embedding，得到 $\{e_C, e_1, e_2, e_3, e_4, e_S\}$。
#
# 3.在BERT内部，会经历多层的TransformerEncoder，最终的得到输出向量 $H^c=\{h_C^c, h_1^c, h_2^c, h_3^c, h_4^c, h_S^c\}$.
#
# 4.将BERT的输出 $H^c$ 和 隔壁Detection Network输出的 $H^d$ 进行融合，得到 $H = H^d+H^c$
#
# > 融合时并不对`[CLS]`和`[SEP]`进行融合
#
# 5.将$H$送给全连接层(Dense Layer)做最后的预测。
#
# <br>
#
# **Correction Network模型细节**：
#
# 1. **BERT**：作者使用的是具有12层Transformer Block的BERT-base版。
# 2. **Dense Layer**：Dense Layer的输入通道为词向量维度，输出通道为词典大小。例如：词向量维度为768，词典大小为20000，则Dense Layer则为`nn.Linear(768, 20000)`
# 3. **Dense Layer的初始化**：Dense Layer的权重使用的是Word Embedding的参数。因为word Embedding是将词index转成词向量，所以其参数刚好是Dense Layer的转置，即Word Embedding是`nn.Linear(20000, 768)`，所以作者就是用Word Embedding的转置来初始化Dense Layer的参数。因为这样可以加速训练，且使模型变的稳定。
#
# ---
#
# **Detection Network**的数据流向如下：
#
# 1.输入为使用BERT得到的word Embedding $\{e_1^w, e_2^w, e_3^w, e_4^w\}$。虽然图里并不包含`[CLS]`和`[SEP]`的词向量，但个人认为不需要对其特殊处理，因为最后的预测也用不到这两个token.
#
# 2.将$\{e_1^w, e_2^w, e_3^w, e_4^w\}$增加Position Embedding信息，得到$\{e_1', e_2', e_3', e_4'\}$
#
# > 在论文中说Detection Network使用的是向量$\{e_1, e_2, e_3, e_4\}$，其是word embedding+position embedding+segment embedding。这与图上是矛盾的，这里以图为准了。
#
# 3.将$\{e_1', e_2', e_3', e_4'\}$向量送入Transformer Block，得到输出向量$H^d=\{h_1^d, h_2^d, h_3^d, h_4^d\}$
#
# 4.一方面，将输出向量$H^d$送给隔壁的Correction Network进行融合；另一方面，将$H^d$送给后续的全连接层(Dense Layer)来判断哪个token是错误的.
#
# **Detection Network**的细节：
#
# 1. **Transformer Block**：Transformer Block是2层的TransformerEncoder。
# 2. **Transformer Block参数初始化**：Transformer Block参数初始化使用的是BERT的权重。
# 3. **Dense Layer**：Dense Layer的输入通道为词向量大小，输出通道为1。使用Sigmoid来判别该token为错字的概率。

# %%
class CorrectionNetwork(nn.Module):

    def __init__(self):
        super(CorrectionNetwork, self).__init__()
        # BERT分词器，作者并没提到自己使用的是哪个中文版的bert，我这里就使用一个比较常用的
        self.tokenizer = AutoTokenizer.from_pretrained("hfl/chinese-roberta-wwm-ext")
        # BERT
        self.bert = AutoModel.from_pretrained("hfl/chinese-roberta-wwm-ext")
        # BERT的word embedding，本质就是个nn.Embedding
        self.word_embedding_table = self.bert.get_input_embeddings()
        # 预测层。hidden_size是词向量的大小，len(self.tokenizer)是词典大小
        self.dense_layer = nn.Linear(self.bert.config.hidden_size, len(self.tokenizer))

    def forward(self, inputs, word_embeddings, detect_hidden_states):
        """
        Correction Network的前向传递
        :param inputs: inputs为tokenizer对中文文本的分词结果，
                       里面包含了token对一个的index，attention_mask等
        :param word_embeddings: 使用BERT的word_embedding对token进行embedding后的结果
        :param detect_hidden_states: Detection Network输出hidden state
        :return: Correction Network对个token的预测结果。
        """
        # 1. 使用bert进行前向传递
        bert_outputs = self.bert(token_type_ids=inputs['token_type_ids'],
                                 attention_mask=inputs['attention_mask'],
                                 inputs_embeds=word_embeddings)
        # 2. 将bert的hidden_state和Detection Network的hidden state进行融合。
        hidden_states = bert_outputs['last_hidden_state'] + detect_hidden_states
        # 3. 最终使用全连接层进行token预测
        return self.dense_layer(hidden_states)

    def get_inputs_and_word_embeddings(self, sequences, max_length=128):
        """
        对中文序列进行分词和word embeddings处理
        :param sequences: 中文文本序列。例如: ["鸡你太美", "哎呦，你干嘛！"]
        :param max_length: 文本的最大长度，不足则进行填充，超出进行裁剪。
        :return: tokenizer的输出和word embeddings.
        """
        inputs = self.tokenizer(sequences, padding='max_length', max_length=max_length, return_tensors='pt',
                                truncation=True).to(device)
        # 使用BERT的work embeddings对token进行embedding，这里得到的embedding并不包含position embedding和segment embedding
        word_embeddings = self.word_embedding_table(inputs['input_ids'])
        return inputs, word_embeddings

# %%
class DetectionNetwork(nn.Module):

    def __init__(self, position_embeddings, transformer_blocks, hidden_size):
        """
        :param position_embeddings: bert的position_embeddings，本质是一个nn.Embedding
        :param transformer: BERT的前两层transformer_block，其是一个ModuleList对象
        """
        super(DetectionNetwork, self).__init__()
        self.position_embeddings = position_embeddings
        self.transformer_blocks = transformer_blocks

        # 定义最后的预测层，预测哪个token是错误的
        self.dense_layer = nn.Sequential(
            nn.Linear(hidden_size, 1),
            nn.Sigmoid()
        )

    def forward(self, word_embeddings):
        # 获取token序列的长度，这里为128
        sequence_length = word_embeddings.size(1)
        # 生成position embedding
        position_embeddings = self.position_embeddings(torch.LongTensor(range(sequence_length)).to(device))
        # 融合work_embedding和position_embedding
        x = word_embeddings + position_embeddings
        # 将x一层一层的使用transformer encoder进行向后传递
        for transformer_layer in self.transformer_blocks:
            x = transformer_layer(x)[0]

        # 最终返回Detection Network输出的hidden states和预测结果
        hidden_states = x
        return hidden_states, self.dense_layer(hidden_states)

# %%
class MDCSpellModel(nn.Module):

    def __init__(self):
        super(MDCSpellModel, self).__init__()
        # 构造Correction Network
        self.correction_network = CorrectionNetwork()
        self._init_correction_dense_layer()

        # 构造Detection Network
        # position embedding使用BERT的
        position_embeddings = self.correction_network.bert.embeddings.position_embeddings
        # 作者在论文中提到的，Detection Network的Transformer使用BERT的权重
        # 所以我这里直接克隆BERT的前两层Transformer来完成这个动作
        transformer = copy.deepcopy(self.correction_network.bert.encoder.layer[:2])
        # 提取BERT的词向量大小
        hidden_size = self.correction_network.bert.config.hidden_size

        # 构造Detection Network
        self.detection_network = DetectionNetwork(position_embeddings, transformer, hidden_size)

    def forward(self, sequences, max_length=128):
        # 先获取word embedding，Correction Network和Detection Network都要用
        inputs, word_embeddings = self.correction_network.get_inputs_and_word_embeddings(sequences, max_length)
        # Detection Network进行前向传递，获取输出的Hidden State和预测结果
        hidden_states, detection_outputs = self.detection_network(word_embeddings)
        # Correction Network进行前向传递，获取其预测结果
        correction_outputs = self.correction_network(inputs, word_embeddings, hidden_states)
        # 返回Correction Network 和 Detection Network 的预测结果。
        # 在计算损失时`[PAD]`token不需要参与计算，所以这里将`[PAD]`部分全都变为0
        return correction_outputs, detection_outputs.squeeze(2) * inputs['attention_mask']

    def _init_correction_dense_layer(self):
        """
        原论文中提到，使用Word Embedding的weight来对Correction Network进行初始化
        """
        self.correction_network.dense_layer.weight.data = self.correction_network.word_embedding_table.weight.data

# %% [markdown]
# 定义好模型后，我们来简单的尝试一下：

# %%
model = MDCSpellModel().to(device)
correction_outputs, detection_outputs = model(["鸡你太美", "哎呦，你干嘛！"])
print("correction_outputs shape:", correction_outputs.size())
print("detection_outputs shape:", detection_outputs.size())
# Out:
# Downloading tokenizer_config.json:   0%|          | 0.00/19.0 [00:00<?, ?B/s]
# Downloading config.json:   0%|          | 0.00/689 [00:00<?, ?B/s]
# Downloading vocab.txt:   0%|          | 0.00/107k [00:00<?, ?B/s]
# Downloading tokenizer.json:   0%|          | 0.00/263k [00:00<?, ?B/s]
# Downloading added_tokens.json:   0%|          | 0.00/2.00 [00:00<?, ?B/s]
# Downloading special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/393M [00:00<?, ?B/s]
# Some weights of the model checkpoint at hfl/chinese-roberta-wwm-ext were not used when initializing BertModel: ['cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# correction_outputs shape: torch.Size([2, 128, 21128])
# detection_outputs shape: torch.Size([2, 128])

# %% [markdown]
# # 损失函数

# %% [markdown]
# Correction Network和Detection Network使用的都是Cross Entropy。之后进行相加即可：
#
# $$
# L = \lambda L^c + (1-\lambda) L^d
# $$
#
# 其中 $\lambda \in [0,1]$ 。作者通过实验得出 $\lambda=0.85$ 时效果最好。

# %%
class MDCSpellLoss(nn.Module):

    def __init__(self, coefficient=0.85):
        super(MDCSpellLoss, self).__init__()
        # 定义Correction Network的Loss函数
        self.correction_criterion = nn.CrossEntropyLoss(ignore_index=0)
        # 定义Detection Network的Loss函数，因为是二分类，所以用Binary Cross Entropy
        self.detection_criterion = nn.BCELoss()
        # 权重系数
        self.coefficient = coefficient

    def forward(self, correction_outputs, correction_targets, detection_outputs, detection_targets):
        """
        :param correction_outputs: Correction Network的输出，Shape为(batch_size, sequence_length, hidden_size)
        :param correction_targets: Correction Network的标签，Shape为(batch_size, sequence_length)
        :param detection_outputs: Detection Network的输出，Shape为(batch_size, sequence_length)
        :param detection_targets: Detection Network的标签，Shape为(batch_size, sequence_length)
        :return:
        """
        # 计算Correction Network的loss，因为Shape维度为3，所以要把batch_size和sequence_length进行合并才能计算
        correction_loss = self.correction_criterion(correction_outputs.view(-1, correction_outputs.size(2)),
                                                    correction_targets.view(-1))
        # 计算Detection Network的loss
        detection_loss = self.detection_criterion(detection_outputs, detection_targets)
        # 对两个loss进行加权平均
        return self.coefficient * correction_loss + (1 - self.coefficient) * detection_loss

# %% [markdown]
# # 模型训练

# %% [markdown]
# 作者的训练方式：
#
# 1. 第一步，首先使用 [Wang271K(自己造的假数据)](https://github.com/wdimmy/Automatic-Corpus-Generation) 数据集进行训练。batch size为32， learning rate为2e-5
#
# 2. 第二步，使用SIGHAN训练集进行fine-tune。 batch size为32，learning rate为1e-5
#
# > 作者并没有提到使用的是什么Optimizer，但看这个学习率，应该是Adam。
#
# > 在第一步，作者说的是使用了几乎3M个，但作者只提到过Wang271K这个数据集，我猜可能作者看错了，这个是0.3M条数据，而不是3M。

# %% [markdown]
# 作者首先使用了Wang271K数据集进行对模型进行训练，然后又使用SIGHAN训练集对模型进行fine-tune。这里我就不进行fine-tune了，直接进行训练。我这里使用的是 [ReaLiSe](https://github.com/DaDaMrX/ReaLiSe)论文 处理好的数据集，其就是Wang271K和SIGHAN。
#
# [百度网盘链接](https://pan.baidu.com/s/1x67LPiYAjLKhO1_2CI6aOA?pwd=skda) ：https://pan.baidu.com/s/1x67LPiYAjLKhO1_2CI6aOA?pwd=skda
#
# 下载好直接解压即可。

# %%
# !gdown '1dC09i57lobL91lEbpebDuUBS0fGz-LAk' --folder --output data
# Out:
# 'gdown' 不是内部或外部命令，也不是可运行的程序
# 或批处理文件。

# %% [markdown]
# ## 构造Dataset

# %%
class CSCDataset(Dataset):

    def __init__(self):
        super(CSCDataset, self).__init__()
        with open("data/trainall.times2.pkl", mode='br') as f:
            train_data = pickle.load(f)

        self.train_data = train_data

    def __getitem__(self, index):
        src = self.train_data[index]['src']
        tgt = self.train_data[index]['tgt']
        return src, tgt

    def __len__(self):
        return len(self.train_data)

# %%
train_data = CSCDataset()

# %%
train_data.__getitem__(0)
# Out:
# ('纽约早盘作为基准的低硫轻油，五月份交割价攀升一点三四美元，来到每桶二十八点二五美元，而上周五曾下挫一豪元以上。',
#  '纽约早盘作为基准的低硫轻油，五月份交割价攀升一点三四美元，来到每桶二十八点二五美元，而上周五曾下挫一美元以上。')

# %% [markdown]
# ## 构造Dataloader

# %%
tokenizer = AutoTokenizer.from_pretrained("hfl/chinese-roberta-wwm-ext")

# %%
def collate_fn(batch):
    src, tgt = zip(*batch)
    src, tgt = list(src), list(tgt)

    src_tokens = tokenizer(src, padding='max_length', max_length=128, return_tensors='pt', truncation=True)['input_ids']
    tgt_tokens = tokenizer(tgt, padding='max_length', max_length=128, return_tensors='pt', truncation=True)['input_ids']

    correction_targets = tgt_tokens
    detection_targets = (src_tokens != tgt_tokens).float()
    return src, correction_targets, detection_targets, src_tokens  # src_tokens在计算Correction的精准率时要用到

# %%
train_loader = DataLoader(train_data, batch_size=batch_size, collate_fn=collate_fn, shuffle=True)

# %% [markdown]
# ## 训练

# %%
criterion = MDCSpellLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=2e-5)
start_epoch = 0  # 从哪个epoch开始
total_step = 0  # 一共更新了多少次参数

# %%
# 恢复之前的训练
if os.path.exists(model_path):
    if not torch.cuda.is_available():
        checkpoint = torch.load(model_path, map_location='cpu')
    else:
        checkpoint = torch.load(model_path)
    model.load_state_dict(checkpoint['model'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    start_epoch = checkpoint['epoch']
    total_step = checkpoint['total_step']
    print("恢复训练，epoch:", start_epoch)

# %%
model = model.to(device)
model = model.train()

# %% [markdown]
# 训练这里代码量看起来很大，但实际大多都是计算recall和precision的代码。这里对于Detection的recall和precision的计算使用的是Detection Network的预测结果。

# %%
total_loss = 0.  # 记录loss

d_recall_numerator = 0  # Detection的Recall的分子
d_recall_denominator = 0  # Detection的Recall的分母
d_precision_numerator = 0  # Detection的precision的分子
d_precision_denominator = 0  # Detection的precision的分母
c_recall_numerator = 0  # Correction的Recall的分子
c_recall_denominator = 0  # Correction的Recall的分母
c_precision_numerator = 0  # Correction的precision的分子
c_precision_denominator = 0  # Correction的precision的分母

for epoch in range(start_epoch, epochs):

    step = 0

    for sequences, correction_targets, detection_targets, correction_inputs in train_loader:
        correction_targets, detection_targets = correction_targets.to(device), detection_targets.to(device)
        correction_inputs = correction_inputs.to(device)
        correction_outputs, detection_outputs = model(sequences)
        loss = criterion(correction_outputs, correction_targets, detection_outputs, detection_targets)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

        step += 1
        total_step += 1

        total_loss += loss.detach().item()

        # 计算Detection的recall和precision指标
        # 大于0.5，认为是错误token，反之为正确token
        d_predicts = detection_outputs >= 0.5
        # 计算错误token中被网络正确预测到的数量
        d_recall_numerator += d_predicts[detection_targets == 1].sum().item()
        # 计算错误token的数量
        d_recall_denominator += (detection_targets == 1).sum().item()
        # 计算网络预测的错误token的数量
        d_precision_denominator += d_predicts.sum().item()
        # 计算网络预测的错误token中，有多少是真错误的token
        d_precision_numerator += (detection_targets[d_predicts == 1]).sum().item()

        # 计算Correction的recall和precision
        # 将输出映射成index，即将correction_outputs的Shape由(32, 128, 21128)变为(32,128)
        correction_outputs = correction_outputs.argmax(2)
        # 对于填充、[CLS]和[SEP]这三个token不校验
        correction_outputs[(correction_targets == 0) | (correction_targets == 101) | (correction_targets == 102)] = 0
        # correction_targets的[CLS]和[SEP]也要变为0
        correction_targets[(correction_targets == 101) | (correction_targets == 102)] = 0
        # Correction的预测结果，其中True表示预测正确，False表示预测错误或无需预测
        c_predicts = correction_outputs == correction_targets
        # 计算错误token中被网络正确纠正的token数量
        c_recall_numerator += c_predicts[detection_targets == 1].sum().item()
        # 计算错误token的数量
        c_recall_denominator += (detection_targets == 1).sum().item()
        # 计算网络纠正token的数量
        correction_inputs[(correction_inputs == 101) | (correction_inputs == 102)] = 0
        c_precision_denominator += (correction_outputs != correction_inputs).sum().item()
        # 计算在网络纠正的这些token中，有多少是真正被纠正对的
        c_precision_numerator += c_predicts[correction_outputs != correction_inputs].sum().item()

        if total_step % log_after_step == 0:
            loss = total_loss / log_after_step
            d_recall = d_recall_numerator / (d_recall_denominator + 1e-9)
            d_precision = d_precision_numerator / (d_precision_denominator + 1e-9)
            c_recall = c_recall_numerator / (c_recall_denominator + 1e-9)
            c_precision = c_precision_numerator / (c_precision_denominator + 1e-9)

            print("Epoch {}, "
                  "Step {}/{}, "
                  "Total Step {}, "
                  "loss {:.5f}, "
                  "detection recall {:.4f}, "
                  "detection precision {:.4f}, "
                  "correction recall {:.4f}, "
                  "correction precision {:.4f}".format(epoch, step, len(train_loader), total_step,
                                                       loss,
                                                       d_recall,
                                                       d_precision,
                                                       c_recall,
                                                       c_precision))

            total_loss = 0.
            total_correct = 0
            total_num = 0
            d_recall_numerator = 0
            d_recall_denominator = 0
            d_precision_numerator = 0
            d_precision_denominator = 0
            c_recall_numerator = 0
            c_recall_denominator = 0
            c_precision_numerator = 0
            c_precision_denominator = 0

    torch.save({
        'model': model.state_dict(),
        'optimizer': optimizer.state_dict(),
        'epoch': epoch + 1,
        'total_step': total_step,
    }, model_path)
# Out:
# Epoch 0, Step 20/8882, Total Step 20, loss 0.94743, detection recall 0.5820, detection precision 0.0327, correction recall 0.0000, correction precision 0.0000
# Epoch 0, Step 40/8882, Total Step 40, loss 0.36999, detection recall 0.0065, detection precision 0.0279, correction recall 0.0000, correction precision 0.0000
# Epoch 0, Step 60/8882, Total Step 60, loss 0.30299, detection recall 0.0000, detection precision 0.0000, correction recall 0.0064, correction precision 0.0249
# Epoch 0, Step 80/8882, Total Step 80, loss 0.25096, detection recall 0.0000, detection precision 0.0000, correction recall 0.0381, correction precision 0.1741
# Epoch 0, Step 100/8882, Total Step 100, loss 0.23453, detection recall 0.0000, detection precision 0.0000, correction recall 0.0560, correction precision 0.2301
# Epoch 0, Step 120/8882, Total Step 120, loss 0.22107, detection recall 0.0000, detection precision 0.0000, correction recall 0.0796, correction precision 0.3518
# Epoch 0, Step 140/8882, Total Step 140, loss 0.22011, detection recall 0.0000, detection precision 0.0000, correction recall 0.0958, correction precision 0.3478
# Epoch 0, Step 160/8882, Total Step 160, loss 0.20159, detection recall 0.0000, detection precision 0.0000, correction recall 0.1208, correction precision 0.4332
# Epoch 0, Step 180/8882, Total Step 180, loss 0.19817, detection recall 0.0000, detection precision 0.0000, correction recall 0.1672, correction precision 0.5611
# Epoch 0, Step 200/8882, Total Step 200, loss 0.17926, detection recall 0.0000, detection precision 0.0000, correction recall 0.1769, correction precision 0.4968
# Epoch 0, Step 220/8882, Total Step 220, loss 0.19834, detection recall 0.0000, detection precision 0.0000, correction recall 0.1558, correction precision 0.4519
# Epoch 0, Step 240/8882, Total Step 240, loss 0.18942, detection recall 0.0000, detection precision 0.0000, correction recall 0.1733, correction precision 0.4923
# Epoch 0, Step 260/8882, Total Step 260, loss 0.18345, detection recall 0.0000, detection precision 0.0000, correction recall 0.1738, correction precision 0.4874
# Epoch 0, Step 280/8882, Total Step 280, loss 0.18199, detection recall 0.0000, detection precision 0.0000, correction recall 0.1905, correction precision 0.5677
# Epoch 0, Step 300/8882, Total Step 300, loss 0.17107, detection recall 0.0000, detection precision 0.0000, correction recall 0.2144, correction precision 0.5411
# Epoch 0, Step 320/8882, Total Step 320, loss 0.16803, detection recall 0.0000, detection precision 0.0000, correction recall 0.2196, correction precision 0.5361
# Epoch 0, Step 340/8882, Total Step 340, loss 0.17315, detection recall 0.0000, detection precision 0.0000, correction recall 0.2418, correction precision 0.5678
# Epoch 0, Step 360/8882, Total Step 360, loss 0.16740, detection recall 0.0000, detection precision 0.0000, correction recall 0.2522, correction precision 0.5736
# Epoch 0, Step 380/8882, Total Step 380, loss 0.16571, detection recall 0.0000, detection precision 0.0000, correction recall 0.2306, correction precision 0.5524
# Epoch 0, Step 400/8882, Total Step 400, loss 0.16399, detection recall 0.0000, detection precision 0.0000, correction recall 0.2355, correction precision 0.5750
# Epoch 0, Step 420/8882, Total Step 420, loss 0.16778, detection recall 0.0000, detection precision 0.0000, correction recall 0.2303, correction precision 0.5734
# Epoch 0, Step 440/8882, Total Step 440, loss 0.15309, detection recall 0.0000, detection precision 0.0000, correction recall 0.2680, correction precision 0.6136
# Epoch 0, Step 460/8882, Total Step 460, loss 0.15542, detection recall 0.0000, detection precision 0.0000, correction recall 0.2661, correction precision 0.6356
# Epoch 0, Step 480/8882, Total Step 480, loss 0.15163, detection recall 0.0000, detection precision 0.0000, correction recall 0.2520, correction precision 0.5703
# Epoch 0, Step 500/8882, Total Step 500, loss 0.14780, detection recall 0.0000, detection precision 0.0000, correction recall 0.2964, correction precision 0.6221
# Epoch 0, Step 520/8882, Total Step 520, loss 0.15232, detection recall 0.0000, detection precision 0.0000, correction recall 0.3107, correction precision 0.6772
# Epoch 0, Step 540/8882, Total Step 540, loss 0.14674, detection recall 0.0000, detection precision 0.0000, correction recall 0.3000, correction precision 0.6323
# Epoch 0, Step 560/8882, Total Step 560, loss 0.15179, detection recall 0.0000, detection precision 0.0000, correction recall 0.2752, correction precision 0.6225
# Epoch 0, Step 580/8882, Total Step 580, loss 0.15364, detection recall 0.0000, detection precision 0.0000, correction recall 0.2905, correction precision 0.6468
# Epoch 0, Step 600/8882, Total Step 600, loss 0.13915, detection recall 0.0000, detection precision 0.0000, correction recall 0.3010, correction precision 0.6519
# Epoch 0, Step 620/8882, Total Step 620, loss 0.14845, detection recall 0.0000, detection precision 0.0000, correction recall 0.3029, correction precision 0.6270
# Epoch 0, Step 640/8882, Total Step 640, loss 0.13842, detection recall 0.0000, detection precision 0.0000, correction recall 0.3020, correction precision 0.6528
# Epoch 0, Step 660/8882, Total Step 660, loss 0.13114, detection recall 0.0000, detection precision 0.0000, correction recall 0.3310, correction precision 0.6575
# Epoch 0, Step 680/8882, Total Step 680, loss 0.14302, detection recall 0.0000, detection precision 0.0000, correction recall 0.2985, correction precision 0.6159
# Epoch 0, Step 700/8882, Total Step 700, loss 0.14026, detection recall 0.0000, detection precision 0.0000, correction recall 0.3259, correction precision 0.6854
# Epoch 0, Step 720/8882, Total Step 720, loss 0.14051, detection recall 0.0000, detection precision 0.0000, correction recall 0.3224, correction precision 0.6323
# Epoch 0, Step 740/8882, Total Step 740, loss 0.14018, detection recall 0.0000, detection precision 0.0000, correction recall 0.3400, correction precision 0.6696
# Epoch 0, Step 760/8882, Total Step 760, loss 0.13442, detection recall 0.0000, detection precision 0.0000, correction recall 0.3349, correction precision 0.6903
# Epoch 0, Step 780/8882, Total Step 780, loss 0.12840, detection recall 0.0000, detection precision 0.0000, correction recall 0.3664, correction precision 0.6566
# Epoch 0, Step 800/8882, Total Step 800, loss 0.13126, detection recall 0.0000, detection precision 0.0000, correction recall 0.3484, correction precision 0.6891
# Epoch 0, Step 820/8882, Total Step 820, loss 0.12121, detection recall 0.0000, detection precision 0.0000, correction recall 0.3561, correction precision 0.6639
# Epoch 0, Step 840/8882, Total Step 840, loss 0.13483, detection recall 0.0000, detection precision 0.0000, correction recall 0.3575, correction precision 0.6954
# Epoch 0, Step 860/8882, Total Step 860, loss 0.13280, detection recall 0.0000, detection precision 0.0000, correction recall 0.3451, correction precision 0.6901
# Epoch 0, Step 880/8882, Total Step 880, loss 0.12449, detection recall 0.0000, detection precision 0.0000, correction recall 0.3657, correction precision 0.6586
# Epoch 0, Step 900/8882, Total Step 900, loss 0.12580, detection recall 0.0000, detection precision 0.0000, correction recall 0.3810, correction precision 0.7242
# Epoch 0, Step 920/8882, Total Step 920, loss 0.13141, detection recall 0.0000, detection precision 0.0000, correction recall 0.3480, correction precision 0.6536
# Epoch 0, Step 940/8882, Total Step 940, loss 0.12529, detection recall 0.0000, detection precision 0.0000, correction recall 0.3632, correction precision 0.7049
# Epoch 0, Step 960/8882, Total Step 960, loss 0.12471, detection recall 0.0000, detection precision 0.0000, correction recall 0.3794, correction precision 0.6957
# Epoch 0, Step 980/8882, Total Step 980, loss 0.12927, detection recall 0.0000, detection precision 0.0000, correction recall 0.3549, correction precision 0.6809
# Epoch 0, Step 1000/8882, Total Step 1000, loss 0.12744, detection recall 0.0000, detection precision 0.0000, correction recall 0.3617, correction precision 0.6972
# Epoch 0, Step 1020/8882, Total Step 1020, loss 0.11720, detection recall 0.0011, detection precision 1.0000, correction recall 0.3885, correction precision 0.7263
# Epoch 0, Step 1040/8882, Total Step 1040, loss 0.12448, detection recall 0.0011, detection precision 1.0000, correction recall 0.3585, correction precision 0.6627
# Epoch 0, Step 1060/8882, Total Step 1060, loss 0.11686, detection recall 0.0011, detection precision 1.0000, correction recall 0.3834, correction precision 0.6808
# Epoch 0, Step 1080/8882, Total Step 1080, loss 0.12098, detection recall 0.0011, detection precision 1.0000, correction recall 0.3881, correction precision 0.6970
# Epoch 0, Step 1100/8882, Total Step 1100, loss 0.12629, detection recall 0.0045, detection precision 1.0000, correction recall 0.3922, correction precision 0.7105
# Epoch 0, Step 1120/8882, Total Step 1120, loss 0.11968, detection recall 0.0056, detection precision 1.0000, correction recall 0.3839, correction precision 0.7078
# Epoch 0, Step 1140/8882, Total Step 1140, loss 0.11445, detection recall 0.0067, detection precision 0.8571, correction recall 0.4076, correction precision 0.6919
# Epoch 0, Step 1160/8882, Total Step 1160, loss 0.10736, detection recall 0.0045, detection precision 1.0000, correction recall 0.4101, correction precision 0.7359
# Epoch 0, Step 1180/8882, Total Step 1180, loss 0.11391, detection recall 0.0087, detection precision 0.8889, correction recall 0.4009, correction precision 0.7063
# Epoch 0, Step 1200/8882, Total Step 1200, loss 0.11274, detection recall 0.0231, detection precision 0.8400, correction recall 0.4171, correction precision 0.7436
# Epoch 0, Step 1220/8882, Total Step 1220, loss 0.11760, detection recall 0.0045, detection precision 0.5000, correction recall 0.4058, correction precision 0.7054
# Epoch 0, Step 1240/8882, Total Step 1240, loss 0.11172, detection recall 0.0111, detection precision 0.7692, correction recall 0.4154, correction precision 0.7328
# Epoch 0, Step 1260/8882, Total Step 1260, loss 0.11635, detection recall 0.0265, detection precision 0.6857, correction recall 0.4237, correction precision 0.7351
# Epoch 0, Step 1280/8882, Total Step 1280, loss 0.10955, detection recall 0.0376, detection precision 0.7391, correction recall 0.4144, correction precision 0.7170
# Epoch 0, Step 1300/8882, Total Step 1300, loss 0.11996, detection recall 0.0371, detection precision 0.8095, correction recall 0.4188, correction precision 0.7178
# Epoch 0, Step 1320/8882, Total Step 1320, loss 0.12201, detection recall 0.0210, detection precision 0.7917, correction recall 0.3832, correction precision 0.7047
# Epoch 0, Step 1340/8882, Total Step 1340, loss 0.10203, detection recall 0.0448, detection precision 0.7800, correction recall 0.4420, correction precision 0.7432
# Epoch 0, Step 1360/8882, Total Step 1360, loss 0.11248, detection recall 0.0263, detection precision 0.7059, correction recall 0.4463, correction precision 0.7468
# Epoch 0, Step 1380/8882, Total Step 1380, loss 0.10327, detection recall 0.0504, detection precision 0.6479, correction recall 0.4803, correction precision 0.7386
# Epoch 0, Step 1400/8882, Total Step 1400, loss 0.10609, detection recall 0.0628, detection precision 0.7467, correction recall 0.4664, correction precision 0.7495
# Epoch 0, Step 1420/8882, Total Step 1420, loss 0.10172, detection recall 0.0535, detection precision 0.7015, correction recall 0.4539, correction precision 0.7389
# Epoch 0, Step 1440/8882, Total Step 1440, loss 0.10463, detection recall 0.0586, detection precision 0.7647, correction recall 0.4493, correction precision 0.7528
# Epoch 0, Step 1460/8882, Total Step 1460, loss 0.10377, detection recall 0.0872, detection precision 0.7700, correction recall 0.4394, correction precision 0.7055
# Epoch 0, Step 1480/8882, Total Step 1480, loss 0.10032, detection recall 0.0805, detection precision 0.6283, correction recall 0.4603, correction precision 0.7748
# Epoch 0, Step 1500/8882, Total Step 1500, loss 0.09867, detection recall 0.0746, detection precision 0.8148, correction recall 0.4701, correction precision 0.7509
# Epoch 0, Step 1520/8882, Total Step 1520, loss 0.11265, detection recall 0.0734, detection precision 0.7065, correction recall 0.4418, correction precision 0.7254
# Epoch 0, Step 1540/8882, Total Step 1540, loss 0.10344, detection recall 0.0885, detection precision 0.7615, correction recall 0.4723, correction precision 0.7704
# Epoch 0, Step 1560/8882, Total Step 1560, loss 0.09841, detection recall 0.0842, detection precision 0.7624, correction recall 0.4612, correction precision 0.7352
# Epoch 0, Step 1580/8882, Total Step 1580, loss 0.09979, detection recall 0.0968, detection precision 0.7788, correction recall 0.4796, correction precision 0.7636
# Epoch 0, Step 1600/8882, Total Step 1600, loss 0.10286, detection recall 0.1111, detection precision 0.7886, correction recall 0.4376, correction precision 0.7318
# Epoch 0, Step 1620/8882, Total Step 1620, loss 0.11477, detection recall 0.1151, detection precision 0.7143, correction recall 0.4582, correction precision 0.7411
# Epoch 0, Step 1640/8882, Total Step 1640, loss 0.09879, detection recall 0.1518, detection precision 0.7158, correction recall 0.4721, correction precision 0.7747
# Epoch 0, Step 1660/8882, Total Step 1660, loss 0.09834, detection recall 0.1155, detection precision 0.7338, correction recall 0.4813, correction precision 0.7576
# Epoch 0, Step 1680/8882, Total Step 1680, loss 0.10046, detection recall 0.1115, detection precision 0.7405, correction recall 0.4724, correction precision 0.7682
# Epoch 0, Step 1700/8882, Total Step 1700, loss 0.09669, detection recall 0.1367, detection precision 0.7410, correction recall 0.4578, correction precision 0.7370
# Epoch 0, Step 1720/8882, Total Step 1720, loss 0.09815, detection recall 0.1292, detection precision 0.6782, correction recall 0.4732, correction precision 0.7552
# Epoch 0, Step 1740/8882, Total Step 1740, loss 0.09217, detection recall 0.1375, detection precision 0.7806, correction recall 0.5102, correction precision 0.7688
# Epoch 0, Step 1760/8882, Total Step 1760, loss 0.09680, detection recall 0.1642, detection precision 0.7337, correction recall 0.4882, correction precision 0.7535
# Epoch 0, Step 1780/8882, Total Step 1780, loss 0.09293, detection recall 0.1351, detection precision 0.7959, correction recall 0.4919, correction precision 0.7370
# Epoch 0, Step 1800/8882, Total Step 1800, loss 0.09682, detection recall 0.1342, detection precision 0.7949, correction recall 0.5087, correction precision 0.7873
# Epoch 0, Step 1820/8882, Total Step 1820, loss 0.09026, detection recall 0.1831, detection precision 0.7443, correction recall 0.5090, correction precision 0.7639
# Epoch 0, Step 1840/8882, Total Step 1840, loss 0.09822, detection recall 0.1416, detection precision 0.7299, correction recall 0.5028, correction precision 0.7683
# Epoch 0, Step 1860/8882, Total Step 1860, loss 0.09627, detection recall 0.1489, detection precision 0.7243, correction recall 0.4944, correction precision 0.7862
# Epoch 0, Step 1880/8882, Total Step 1880, loss 0.09316, detection recall 0.1520, detection precision 0.7735, correction recall 0.4984, correction precision 0.7997
# Epoch 0, Step 1900/8882, Total Step 1900, loss 0.10150, detection recall 0.1608, detection precision 0.7337, correction recall 0.4791, correction precision 0.7411
# Epoch 0, Step 1920/8882, Total Step 1920, loss 0.08870, detection recall 0.1375, detection precision 0.6932, correction recall 0.4746, correction precision 0.7668
# Epoch 0, Step 1940/8882, Total Step 1940, loss 0.09442, detection recall 0.1759, detection precision 0.6996, correction recall 0.5085, correction precision 0.7996
# Epoch 0, Step 1960/8882, Total Step 1960, loss 0.09188, detection recall 0.1332, detection precision 0.7485, correction recall 0.5066, correction precision 0.7838
# Epoch 0, Step 1980/8882, Total Step 1980, loss 0.09643, detection recall 0.1769, detection precision 0.8229, correction recall 0.4961, correction precision 0.7731
# Epoch 0, Step 2000/8882, Total Step 2000, loss 0.08936, detection recall 0.1922, detection precision 0.7597, correction recall 0.5223, correction precision 0.7859
# Epoch 0, Step 2020/8882, Total Step 2020, loss 0.09573, detection recall 0.2078, detection precision 0.7561, correction recall 0.5028, correction precision 0.7692
# Epoch 0, Step 2040/8882, Total Step 2040, loss 0.08905, detection recall 0.1700, detection precision 0.7525, correction recall 0.5257, correction precision 0.8076
# Epoch 0, Step 2060/8882, Total Step 2060, loss 0.09429, detection recall 0.1818, detection precision 0.7043, correction recall 0.4994, correction precision 0.7835
# Epoch 0, Step 2080/8882, Total Step 2080, loss 0.08464, detection recall 0.1845, detection precision 0.7972, correction recall 0.5404, correction precision 0.7971
# Epoch 0, Step 2100/8882, Total Step 2100, loss 0.08327, detection recall 0.2161, detection precision 0.7423, correction recall 0.5521, correction precision 0.8095
# Epoch 0, Step 2120/8882, Total Step 2120, loss 0.08979, detection recall 0.1945, detection precision 0.7532, correction recall 0.5077, correction precision 0.7831
# Epoch 0, Step 2140/8882, Total Step 2140, loss 0.08170, detection recall 0.2091, detection precision 0.7015, correction recall 0.5339, correction precision 0.8027
# Epoch 0, Step 2160/8882, Total Step 2160, loss 0.09009, detection recall 0.1665, detection precision 0.6934, correction recall 0.5221, correction precision 0.7696
# Epoch 0, Step 2180/8882, Total Step 2180, loss 0.08194, detection recall 0.1766, detection precision 0.7739, correction recall 0.5516, correction precision 0.7964
# Epoch 0, Step 2200/8882, Total Step 2200, loss 0.08411, detection recall 0.1949, detection precision 0.7395, correction recall 0.5116, correction precision 0.7636
# Epoch 0, Step 2220/8882, Total Step 2220, loss 0.09085, detection recall 0.2084, detection precision 0.7186, correction recall 0.5347, correction precision 0.7873
# Epoch 0, Step 2240/8882, Total Step 2240, loss 0.09005, detection recall 0.2014, detection precision 0.7964, correction recall 0.5240, correction precision 0.8063
# Epoch 0, Step 2260/8882, Total Step 2260, loss 0.08826, detection recall 0.2126, detection precision 0.7256, correction recall 0.5396, correction precision 0.7741
# Epoch 0, Step 2280/8882, Total Step 2280, loss 0.09578, detection recall 0.1806, detection precision 0.7421, correction recall 0.5165, correction precision 0.8072
# Epoch 0, Step 2300/8882, Total Step 2300, loss 0.09165, detection recall 0.2431, detection precision 0.7754, correction recall 0.5501, correction precision 0.8052
# Epoch 0, Step 2320/8882, Total Step 2320, loss 0.08797, detection recall 0.1777, detection precision 0.7500, correction recall 0.5307, correction precision 0.7637
# Epoch 0, Step 2340/8882, Total Step 2340, loss 0.09395, detection recall 0.2271, detection precision 0.8031, correction recall 0.5142, correction precision 0.7903
# Epoch 0, Step 2360/8882, Total Step 2360, loss 0.07712, detection recall 0.1988, detection precision 0.7748, correction recall 0.5723, correction precision 0.8182
# Epoch 0, Step 2380/8882, Total Step 2380, loss 0.08977, detection recall 0.2099, detection precision 0.7410, correction recall 0.5372, correction precision 0.8123
# Epoch 0, Step 2400/8882, Total Step 2400, loss 0.07819, detection recall 0.2231, detection precision 0.7606, correction recall 0.5617, correction precision 0.8013
# Epoch 0, Step 2420/8882, Total Step 2420, loss 0.08257, detection recall 0.2206, detection precision 0.7556, correction recall 0.5313, correction precision 0.7794
# Epoch 0, Step 2440/8882, Total Step 2440, loss 0.08512, detection recall 0.1878, detection precision 0.7793, correction recall 0.5249, correction precision 0.7682
# Epoch 0, Step 2460/8882, Total Step 2460, loss 0.08100, detection recall 0.2409, detection precision 0.7823, correction recall 0.5705, correction precision 0.8298
# Epoch 0, Step 2480/8882, Total Step 2480, loss 0.08327, detection recall 0.2258, detection precision 0.7433, correction recall 0.5518, correction precision 0.8158
# Epoch 0, Step 2500/8882, Total Step 2500, loss 0.08459, detection recall 0.2000, detection precision 0.7154, correction recall 0.5514, correction precision 0.8344
# Epoch 0, Step 2520/8882, Total Step 2520, loss 0.07479, detection recall 0.2352, detection precision 0.8207, correction recall 0.5902, correction precision 0.8219
# Epoch 0, Step 2540/8882, Total Step 2540, loss 0.07770, detection recall 0.2316, detection precision 0.7707, correction recall 0.5492, correction precision 0.7954
# Epoch 0, Step 2560/8882, Total Step 2560, loss 0.08061, detection recall 0.2022, detection precision 0.8303, correction recall 0.5587, correction precision 0.8065
# Epoch 0, Step 2580/8882, Total Step 2580, loss 0.07998, detection recall 0.2299, detection precision 0.7926, correction recall 0.5714, correction precision 0.8172
# Epoch 0, Step 2600/8882, Total Step 2600, loss 0.07805, detection recall 0.2325, detection precision 0.8024, correction recall 0.5521, correction precision 0.8020
# Epoch 0, Step 2620/8882, Total Step 2620, loss 0.07240, detection recall 0.2262, detection precision 0.7849, correction recall 0.5993, correction precision 0.8144
# Epoch 0, Step 2640/8882, Total Step 2640, loss 0.07574, detection recall 0.2500, detection precision 0.8000, correction recall 0.5781, correction precision 0.8288
# Epoch 0, Step 2660/8882, Total Step 2660, loss 0.07992, detection recall 0.2244, detection precision 0.7372, correction recall 0.5544, correction precision 0.8114
# Epoch 0, Step 2680/8882, Total Step 2680, loss 0.08513, detection recall 0.2439, detection precision 0.6844, correction recall 0.5523, correction precision 0.8212
# Epoch 0, Step 2700/8882, Total Step 2700, loss 0.08638, detection recall 0.2304, detection precision 0.7639, correction recall 0.5571, correction precision 0.8122
# Epoch 0, Step 2720/8882, Total Step 2720, loss 0.07924, detection recall 0.2130, detection precision 0.7667, correction recall 0.5602, correction precision 0.8107
# Epoch 0, Step 2740/8882, Total Step 2740, loss 0.07312, detection recall 0.2783, detection precision 0.7810, correction recall 0.5916, correction precision 0.8275
# Epoch 0, Step 2760/8882, Total Step 2760, loss 0.07923, detection recall 0.2815, detection precision 0.7553, correction recall 0.5563, correction precision 0.7981
# Epoch 0, Step 2780/8882, Total Step 2780, loss 0.07374, detection recall 0.2405, detection precision 0.8222, correction recall 0.6132, correction precision 0.8299
# Epoch 0, Step 2800/8882, Total Step 2800, loss 0.07213, detection recall 0.2878, detection precision 0.7768, correction recall 0.5998, correction precision 0.8156
# Epoch 0, Step 2820/8882, Total Step 2820, loss 0.07446, detection recall 0.2472, detection precision 0.7870, correction recall 0.5930, correction precision 0.8355
# Epoch 0, Step 2840/8882, Total Step 2840, loss 0.07310, detection recall 0.3015, detection precision 0.7798, correction recall 0.6157, correction precision 0.8657
# Epoch 0, Step 2860/8882, Total Step 2860, loss 0.08348, detection recall 0.2709, detection precision 0.7410, correction recall 0.5430, correction precision 0.7788
# Epoch 0, Step 2880/8882, Total Step 2880, loss 0.07822, detection recall 0.2522, detection precision 0.8436, correction recall 0.5859, correction precision 0.8229
# Epoch 0, Step 2900/8882, Total Step 2900, loss 0.07219, detection recall 0.2640, detection precision 0.7966, correction recall 0.6011, correction precision 0.8106
# Epoch 0, Step 2920/8882, Total Step 2920, loss 0.07986, detection recall 0.2798, detection precision 0.8101, correction recall 0.5727, correction precision 0.8086
# Epoch 0, Step 2940/8882, Total Step 2940, loss 0.07369, detection recall 0.2829, detection precision 0.8038, correction recall 0.5824, correction precision 0.8071
# Epoch 0, Step 2960/8882, Total Step 2960, loss 0.07025, detection recall 0.2933, detection precision 0.7768, correction recall 0.6124, correction precision 0.8346
# Epoch 0, Step 2980/8882, Total Step 2980, loss 0.07285, detection recall 0.2786, detection precision 0.8230, correction recall 0.6193, correction precision 0.8480
# Epoch 0, Step 3000/8882, Total Step 3000, loss 0.07509, detection recall 0.2838, detection precision 0.7853, correction recall 0.5854, correction precision 0.8136
# Epoch 0, Step 3020/8882, Total Step 3020, loss 0.07127, detection recall 0.2955, detection precision 0.7768, correction recall 0.5744, correction precision 0.8128
# Epoch 0, Step 3040/8882, Total Step 3040, loss 0.07441, detection recall 0.3355, detection precision 0.7872, correction recall 0.5989, correction precision 0.8392
# Epoch 0, Step 3060/8882, Total Step 3060, loss 0.07730, detection recall 0.2856, detection precision 0.7297, correction recall 0.5802, correction precision 0.7981
# Epoch 0, Step 3080/8882, Total Step 3080, loss 0.06717, detection recall 0.3547, detection precision 0.7399, correction recall 0.6224, correction precision 0.8395
# Epoch 0, Step 3100/8882, Total Step 3100, loss 0.06875, detection recall 0.3387, detection precision 0.7333, correction recall 0.6078, correction precision 0.8367
# Epoch 0, Step 3120/8882, Total Step 3120, loss 0.07174, detection recall 0.3193, detection precision 0.7680, correction recall 0.6186, correction precision 0.8506
# Epoch 0, Step 3140/8882, Total Step 3140, loss 0.06404, detection recall 0.3558, detection precision 0.7919, correction recall 0.6249, correction precision 0.8341
# Epoch 0, Step 3160/8882, Total Step 3160, loss 0.07192, detection recall 0.3270, detection precision 0.7834, correction recall 0.6038, correction precision 0.8272
# Epoch 0, Step 3180/8882, Total Step 3180, loss 0.07024, detection recall 0.3022, detection precision 0.7636, correction recall 0.6237, correction precision 0.8357
# Epoch 0, Step 3200/8882, Total Step 3200, loss 0.06798, detection recall 0.3205, detection precision 0.8061, correction recall 0.6344, correction precision 0.8483
# Epoch 0, Step 3220/8882, Total Step 3220, loss 0.06654, detection recall 0.3244, detection precision 0.7519, correction recall 0.6243, correction precision 0.8346
# Epoch 0, Step 3240/8882, Total Step 3240, loss 0.07329, detection recall 0.3348, detection precision 0.7824, correction recall 0.5953, correction precision 0.8326
# Epoch 0, Step 3260/8882, Total Step 3260, loss 0.07414, detection recall 0.3273, detection precision 0.7686, correction recall 0.5991, correction precision 0.8519
# Epoch 0, Step 3280/8882, Total Step 3280, loss 0.07445, detection recall 0.3150, detection precision 0.7315, correction recall 0.6013, correction precision 0.8223
# Epoch 0, Step 3300/8882, Total Step 3300, loss 0.06883, detection recall 0.3297, detection precision 0.8043, correction recall 0.6286, correction precision 0.8290
# Epoch 0, Step 3320/8882, Total Step 3320, loss 0.07437, detection recall 0.3069, detection precision 0.7228, correction recall 0.5952, correction precision 0.8111
# Epoch 0, Step 3340/8882, Total Step 3340, loss 0.06824, detection recall 0.3495, detection precision 0.7671, correction recall 0.6194, correction precision 0.8404
# Epoch 0, Step 3360/8882, Total Step 3360, loss 0.07070, detection recall 0.3401, detection precision 0.8162, correction recall 0.6273, correction precision 0.8452
# Epoch 0, Step 3380/8882, Total Step 3380, loss 0.07635, detection recall 0.3134, detection precision 0.7711, correction recall 0.5714, correction precision 0.8177
# Epoch 0, Step 3400/8882, Total Step 3400, loss 0.07408, detection recall 0.3341, detection precision 0.7818, correction recall 0.6171, correction precision 0.8373
# Epoch 0, Step 3420/8882, Total Step 3420, loss 0.06913, detection recall 0.3599, detection precision 0.7569, correction recall 0.6161, correction precision 0.8420
# Epoch 0, Step 3440/8882, Total Step 3440, loss 0.06735, detection recall 0.3148, detection precision 0.8164, correction recall 0.6198, correction precision 0.8307
# Epoch 0, Step 3460/8882, Total Step 3460, loss 0.07230, detection recall 0.3296, detection precision 0.8128, correction recall 0.6002, correction precision 0.8360
# Epoch 0, Step 3480/8882, Total Step 3480, loss 0.06876, detection recall 0.3558, detection precision 0.7732, correction recall 0.6240, correction precision 0.8450
# Epoch 0, Step 3500/8882, Total Step 3500, loss 0.06456, detection recall 0.3380, detection precision 0.7990, correction recall 0.6405, correction precision 0.8476
# Epoch 0, Step 3520/8882, Total Step 3520, loss 0.07275, detection recall 0.3550, detection precision 0.7338, correction recall 0.6305, correction precision 0.8366
# Epoch 0, Step 3540/8882, Total Step 3540, loss 0.06548, detection recall 0.3098, detection precision 0.7849, correction recall 0.6273, correction precision 0.8518
# Epoch 0, Step 3560/8882, Total Step 3560, loss 0.06931, detection recall 0.2901, detection precision 0.7559, correction recall 0.6253, correction precision 0.8536
# Epoch 0, Step 3580/8882, Total Step 3580, loss 0.07016, detection recall 0.3252, detection precision 0.8156, correction recall 0.6102, correction precision 0.8536
# Epoch 0, Step 3600/8882, Total Step 3600, loss 0.06600, detection recall 0.3428, detection precision 0.7889, correction recall 0.6288, correction precision 0.8508
# Epoch 0, Step 3620/8882, Total Step 3620, loss 0.06972, detection recall 0.3641, detection precision 0.7619, correction recall 0.6121, correction precision 0.8354
# Epoch 0, Step 3640/8882, Total Step 3640, loss 0.06236, detection recall 0.3311, detection precision 0.7973, correction recall 0.6523, correction precision 0.8414
# Epoch 0, Step 3660/8882, Total Step 3660, loss 0.06624, detection recall 0.3083, detection precision 0.7855, correction recall 0.6223, correction precision 0.8507
# Epoch 0, Step 3680/8882, Total Step 3680, loss 0.07187, detection recall 0.3466, detection precision 0.7728, correction recall 0.6346, correction precision 0.8439
# Epoch 0, Step 3700/8882, Total Step 3700, loss 0.06826, detection recall 0.3538, detection precision 0.7797, correction recall 0.6264, correction precision 0.8419
# Epoch 0, Step 3720/8882, Total Step 3720, loss 0.07223, detection recall 0.3412, detection precision 0.7407, correction recall 0.6340, correction precision 0.8426
# Epoch 0, Step 3740/8882, Total Step 3740, loss 0.06803, detection recall 0.3344, detection precision 0.7752, correction recall 0.6410, correction precision 0.8406
# Epoch 0, Step 3760/8882, Total Step 3760, loss 0.06230, detection recall 0.3561, detection precision 0.7780, correction recall 0.6599, correction precision 0.8487
# Epoch 0, Step 3780/8882, Total Step 3780, loss 0.06736, detection recall 0.3344, detection precision 0.8177, correction recall 0.6425, correction precision 0.8444
# Epoch 0, Step 3800/8882, Total Step 3800, loss 0.06148, detection recall 0.3666, detection precision 0.7980, correction recall 0.6403, correction precision 0.8495
# Epoch 0, Step 3820/8882, Total Step 3820, loss 0.06023, detection recall 0.3319, detection precision 0.7438, correction recall 0.6604, correction precision 0.8735
# Epoch 0, Step 3840/8882, Total Step 3840, loss 0.06080, detection recall 0.3490, detection precision 0.7795, correction recall 0.6636, correction precision 0.8614
# Epoch 0, Step 3860/8882, Total Step 3860, loss 0.06847, detection recall 0.3667, detection precision 0.8182, correction recall 0.6355, correction precision 0.8255
# Epoch 0, Step 3880/8882, Total Step 3880, loss 0.06623, detection recall 0.3344, detection precision 0.7500, correction recall 0.6437, correction precision 0.8536
# Epoch 0, Step 3900/8882, Total Step 3900, loss 0.05820, detection recall 0.3708, detection precision 0.8222, correction recall 0.6737, correction precision 0.8557
# Epoch 0, Step 3920/8882, Total Step 3920, loss 0.07206, detection recall 0.3680, detection precision 0.7762, correction recall 0.6365, correction precision 0.8675
# Epoch 0, Step 3940/8882, Total Step 3940, loss 0.06188, detection recall 0.3694, detection precision 0.7847, correction recall 0.6475, correction precision 0.8481
# Epoch 0, Step 3960/8882, Total Step 3960, loss 0.06111, detection recall 0.3161, detection precision 0.8200, correction recall 0.6487, correction precision 0.8402
# Epoch 0, Step 3980/8882, Total Step 3980, loss 0.06017, detection recall 0.3359, detection precision 0.7850, correction recall 0.6552, correction precision 0.8277
# Epoch 0, Step 4000/8882, Total Step 4000, loss 0.06326, detection recall 0.3414, detection precision 0.7908, correction recall 0.6300, correction precision 0.8487
# Epoch 0, Step 4020/8882, Total Step 4020, loss 0.06442, detection recall 0.3277, detection precision 0.7918, correction recall 0.6202, correction precision 0.8364
# Epoch 0, Step 4040/8882, Total Step 4040, loss 0.05734, detection recall 0.3890, detection precision 0.7667, correction recall 0.6719, correction precision 0.8650
# Epoch 0, Step 4060/8882, Total Step 4060, loss 0.06378, detection recall 0.3768, detection precision 0.7872, correction recall 0.6517, correction precision 0.8440
# Epoch 0, Step 4080/8882, Total Step 4080, loss 0.06117, detection recall 0.3594, detection precision 0.7470, correction recall 0.6521, correction precision 0.8632
# Epoch 0, Step 4100/8882, Total Step 4100, loss 0.06337, detection recall 0.3548, detection precision 0.8196, correction recall 0.6590, correction precision 0.8684
# Epoch 0, Step 4120/8882, Total Step 4120, loss 0.06401, detection recall 0.3377, detection precision 0.7984, correction recall 0.6568, correction precision 0.8647
# Epoch 0, Step 4140/8882, Total Step 4140, loss 0.06646, detection recall 0.3363, detection precision 0.7907, correction recall 0.6385, correction precision 0.8469
# Epoch 0, Step 4160/8882, Total Step 4160, loss 0.06716, detection recall 0.3150, detection precision 0.8017, correction recall 0.6619, correction precision 0.8726
# Epoch 0, Step 4180/8882, Total Step 4180, loss 0.06211, detection recall 0.3770, detection precision 0.8137, correction recall 0.6787, correction precision 0.8601
# Epoch 0, Step 4200/8882, Total Step 4200, loss 0.05923, detection recall 0.4034, detection precision 0.7795, correction recall 0.6644, correction precision 0.8559
# Epoch 0, Step 4220/8882, Total Step 4220, loss 0.06330, detection recall 0.3679, detection precision 0.7967, correction recall 0.6591, correction precision 0.8654
# Epoch 0, Step 4240/8882, Total Step 4240, loss 0.06475, detection recall 0.3533, detection precision 0.7591, correction recall 0.6636, correction precision 0.8707
# Epoch 0, Step 4260/8882, Total Step 4260, loss 0.05641, detection recall 0.3453, detection precision 0.8235, correction recall 0.6816, correction precision 0.8661
# Epoch 0, Step 4280/8882, Total Step 4280, loss 0.06496, detection recall 0.3594, detection precision 0.7807, correction recall 0.6580, correction precision 0.8584
# Epoch 0, Step 4300/8882, Total Step 4300, loss 0.05902, detection recall 0.3669, detection precision 0.7570, correction recall 0.6648, correction precision 0.8814
# Epoch 0, Step 4320/8882, Total Step 4320, loss 0.06027, detection recall 0.3538, detection precision 0.8191, correction recall 0.6942, correction precision 0.8873
# Epoch 0, Step 4340/8882, Total Step 4340, loss 0.06169, detection recall 0.3501, detection precision 0.7677, correction recall 0.6555, correction precision 0.8802
# Epoch 0, Step 4360/8882, Total Step 4360, loss 0.06860, detection recall 0.3483, detection precision 0.7913, correction recall 0.6613, correction precision 0.8526
# Epoch 0, Step 4380/8882, Total Step 4380, loss 0.06237, detection recall 0.3233, detection precision 0.7945, correction recall 0.6511, correction precision 0.8464
# Epoch 0, Step 4400/8882, Total Step 4400, loss 0.05817, detection recall 0.3567, detection precision 0.7810, correction recall 0.6678, correction precision 0.8525
# Epoch 0, Step 4420/8882, Total Step 4420, loss 0.06299, detection recall 0.3511, detection precision 0.8306, correction recall 0.6420, correction precision 0.8395
# Epoch 0, Step 4440/8882, Total Step 4440, loss 0.06354, detection recall 0.3612, detection precision 0.7910, correction recall 0.6475, correction precision 0.8432
# Epoch 0, Step 4460/8882, Total Step 4460, loss 0.05407, detection recall 0.3847, detection precision 0.7917, correction recall 0.6637, correction precision 0.8465
# Epoch 0, Step 4480/8882, Total Step 4480, loss 0.06291, detection recall 0.3530, detection precision 0.8177, correction recall 0.6748, correction precision 0.8741
# Epoch 0, Step 4500/8882, Total Step 4500, loss 0.05855, detection recall 0.3655, detection precision 0.7740, correction recall 0.6686, correction precision 0.8487
# Epoch 0, Step 4520/8882, Total Step 4520, loss 0.06454, detection recall 0.3568, detection precision 0.7650, correction recall 0.6633, correction precision 0.8657
# Epoch 0, Step 4540/8882, Total Step 4540, loss 0.05850, detection recall 0.3814, detection precision 0.7908, correction recall 0.7129, correction precision 0.8748
# Epoch 0, Step 4560/8882, Total Step 4560, loss 0.05351, detection recall 0.3553, detection precision 0.8346, correction recall 0.6799, correction precision 0.8655
# Epoch 0, Step 4580/8882, Total Step 4580, loss 0.05510, detection recall 0.3876, detection precision 0.7744, correction recall 0.7112, correction precision 0.8745
# Epoch 0, Step 4600/8882, Total Step 4600, loss 0.06412, detection recall 0.3522, detection precision 0.7922, correction recall 0.6630, correction precision 0.8616
# Epoch 0, Step 4620/8882, Total Step 4620, loss 0.05696, detection recall 0.3963, detection precision 0.8056, correction recall 0.6682, correction precision 0.8722
# Epoch 0, Step 4640/8882, Total Step 4640, loss 0.06106, detection recall 0.3539, detection precision 0.8020, correction recall 0.6898, correction precision 0.8787
# Epoch 0, Step 4660/8882, Total Step 4660, loss 0.06245, detection recall 0.3478, detection precision 0.7980, correction recall 0.6674, correction precision 0.8599
# Epoch 0, Step 4680/8882, Total Step 4680, loss 0.06456, detection recall 0.3614, detection precision 0.7740, correction recall 0.6633, correction precision 0.8504
# Epoch 0, Step 4700/8882, Total Step 4700, loss 0.05883, detection recall 0.3892, detection precision 0.7950, correction recall 0.6792, correction precision 0.8627
# Epoch 0, Step 4720/8882, Total Step 4720, loss 0.05703, detection recall 0.3760, detection precision 0.8190, correction recall 0.6907, correction precision 0.8622
# Epoch 0, Step 4740/8882, Total Step 4740, loss 0.05502, detection recall 0.3895, detection precision 0.7704, correction recall 0.6897, correction precision 0.8631
# Epoch 0, Step 4760/8882, Total Step 4760, loss 0.06143, detection recall 0.3757, detection precision 0.8219, correction recall 0.6895, correction precision 0.8747
# Epoch 0, Step 4780/8882, Total Step 4780, loss 0.05291, detection recall 0.3945, detection precision 0.8160, correction recall 0.6990, correction precision 0.8795
# Epoch 0, Step 4800/8882, Total Step 4800, loss 0.05975, detection recall 0.3632, detection precision 0.7614, correction recall 0.6816, correction precision 0.8520
# Epoch 0, Step 4820/8882, Total Step 4820, loss 0.05731, detection recall 0.3909, detection precision 0.8318, correction recall 0.6893, correction precision 0.8669
# Epoch 0, Step 4840/8882, Total Step 4840, loss 0.05808, detection recall 0.3840, detection precision 0.8122, correction recall 0.6970, correction precision 0.8568
# Epoch 0, Step 4860/8882, Total Step 4860, loss 0.05283, detection recall 0.4144, detection precision 0.7691, correction recall 0.7211, correction precision 0.8952
# Epoch 0, Step 4880/8882, Total Step 4880, loss 0.05540, detection recall 0.3881, detection precision 0.8196, correction recall 0.6908, correction precision 0.8838
# Epoch 0, Step 4900/8882, Total Step 4900, loss 0.05445, detection recall 0.3832, detection precision 0.8469, correction recall 0.7028, correction precision 0.8859
# Epoch 0, Step 4920/8882, Total Step 4920, loss 0.06140, detection recall 0.3659, detection precision 0.7573, correction recall 0.6851, correction precision 0.8597
# Epoch 0, Step 4940/8882, Total Step 4940, loss 0.05625, detection recall 0.3625, detection precision 0.8034, correction recall 0.7021, correction precision 0.8805
# Epoch 0, Step 4960/8882, Total Step 4960, loss 0.05242, detection recall 0.3944, detection precision 0.7722, correction recall 0.7112, correction precision 0.8730
# Epoch 0, Step 4980/8882, Total Step 4980, loss 0.05519, detection recall 0.4099, detection precision 0.8243, correction recall 0.6887, correction precision 0.8577
# Epoch 0, Step 5000/8882, Total Step 5000, loss 0.05545, detection recall 0.3554, detection precision 0.7827, correction recall 0.6883, correction precision 0.8797
# Epoch 0, Step 5020/8882, Total Step 5020, loss 0.04801, detection recall 0.3872, detection precision 0.7981, correction recall 0.7210, correction precision 0.8804
# Epoch 0, Step 5040/8882, Total Step 5040, loss 0.05562, detection recall 0.3570, detection precision 0.7749, correction recall 0.6856, correction precision 0.8686
# Epoch 0, Step 5060/8882, Total Step 5060, loss 0.05174, detection recall 0.3707, detection precision 0.7626, correction recall 0.7081, correction precision 0.8973
# Epoch 0, Step 5080/8882, Total Step 5080, loss 0.05715, detection recall 0.3750, detection precision 0.8209, correction recall 0.6955, correction precision 0.8644
# Epoch 0, Step 5100/8882, Total Step 5100, loss 0.05962, detection recall 0.3883, detection precision 0.7920, correction recall 0.6811, correction precision 0.8734
# Epoch 0, Step 5120/8882, Total Step 5120, loss 0.05173, detection recall 0.3836, detection precision 0.8199, correction recall 0.7018, correction precision 0.8601
# Epoch 0, Step 5140/8882, Total Step 5140, loss 0.04886, detection recall 0.3967, detection precision 0.8038, correction recall 0.7316, correction precision 0.9009
# Epoch 0, Step 5160/8882, Total Step 5160, loss 0.05653, detection recall 0.3621, detection precision 0.8216, correction recall 0.6988, correction precision 0.8573
# Epoch 0, Step 5180/8882, Total Step 5180, loss 0.05840, detection recall 0.3830, detection precision 0.7554, correction recall 0.6910, correction precision 0.8759
# Epoch 0, Step 5200/8882, Total Step 5200, loss 0.05475, detection recall 0.4128, detection precision 0.8084, correction recall 0.7143, correction precision 0.8994
# Epoch 0, Step 5220/8882, Total Step 5220, loss 0.05557, detection recall 0.3934, detection precision 0.8036, correction recall 0.6907, correction precision 0.8717
# Epoch 0, Step 5240/8882, Total Step 5240, loss 0.05078, detection recall 0.3958, detection precision 0.7890, correction recall 0.7178, correction precision 0.8845
# Epoch 0, Step 5260/8882, Total Step 5260, loss 0.06278, detection recall 0.3437, detection precision 0.7908, correction recall 0.6718, correction precision 0.8571
# Epoch 0, Step 5280/8882, Total Step 5280, loss 0.04902, detection recall 0.4119, detection precision 0.7860, correction recall 0.7117, correction precision 0.8773
# Epoch 0, Step 5300/8882, Total Step 5300, loss 0.05448, detection recall 0.3725, detection precision 0.7799, correction recall 0.7025, correction precision 0.8722
# Epoch 0, Step 5320/8882, Total Step 5320, loss 0.05368, detection recall 0.3792, detection precision 0.7788, correction recall 0.7010, correction precision 0.8780
# Epoch 0, Step 5340/8882, Total Step 5340, loss 0.04922, detection recall 0.4055, detection precision 0.8229, correction recall 0.7171, correction precision 0.8878
# Epoch 0, Step 5360/8882, Total Step 5360, loss 0.05286, detection recall 0.3810, detection precision 0.8231, correction recall 0.7282, correction precision 0.8905
# Epoch 0, Step 5380/8882, Total Step 5380, loss 0.05230, detection recall 0.3937, detection precision 0.7516, correction recall 0.7081, correction precision 0.8755
# Epoch 0, Step 5400/8882, Total Step 5400, loss 0.05366, detection recall 0.3973, detection precision 0.8100, correction recall 0.6926, correction precision 0.8764
# Epoch 0, Step 5420/8882, Total Step 5420, loss 0.04998, detection recall 0.3903, detection precision 0.8498, correction recall 0.7274, correction precision 0.8931
# Epoch 0, Step 5440/8882, Total Step 5440, loss 0.06207, detection recall 0.4097, detection precision 0.7594, correction recall 0.6896, correction precision 0.8779
# Epoch 0, Step 5460/8882, Total Step 5460, loss 0.05377, detection recall 0.4177, detection precision 0.8106, correction recall 0.7049, correction precision 0.8746
# Epoch 0, Step 5480/8882, Total Step 5480, loss 0.05184, detection recall 0.3959, detection precision 0.8197, correction recall 0.7274, correction precision 0.8857
# Epoch 0, Step 5500/8882, Total Step 5500, loss 0.04841, detection recall 0.4180, detection precision 0.8119, correction recall 0.7255, correction precision 0.8922
# Epoch 0, Step 5520/8882, Total Step 5520, loss 0.05567, detection recall 0.3541, detection precision 0.7813, correction recall 0.6860, correction precision 0.8556
# Epoch 0, Step 5540/8882, Total Step 5540, loss 0.05942, detection recall 0.4006, detection precision 0.8126, correction recall 0.7078, correction precision 0.8858
# Epoch 0, Step 5560/8882, Total Step 5560, loss 0.05329, detection recall 0.4058, detection precision 0.7811, correction recall 0.7057, correction precision 0.8695
# Epoch 0, Step 5580/8882, Total Step 5580, loss 0.04916, detection recall 0.3915, detection precision 0.8067, correction recall 0.7426, correction precision 0.9008
# Epoch 0, Step 5600/8882, Total Step 5600, loss 0.05365, detection recall 0.4158, detection precision 0.8126, correction recall 0.7068, correction precision 0.8721
# Epoch 0, Step 5620/8882, Total Step 5620, loss 0.05080, detection recall 0.3811, detection precision 0.8106, correction recall 0.7283, correction precision 0.8923
# Epoch 0, Step 5640/8882, Total Step 5640, loss 0.04960, detection recall 0.4083, detection precision 0.8086, correction recall 0.7264, correction precision 0.8745
# Epoch 0, Step 5660/8882, Total Step 5660, loss 0.04991, detection recall 0.4027, detection precision 0.7911, correction recall 0.7172, correction precision 0.8614
# Epoch 0, Step 5680/8882, Total Step 5680, loss 0.04257, detection recall 0.3848, detection precision 0.7833, correction recall 0.7637, correction precision 0.9249
# Epoch 0, Step 5700/8882, Total Step 5700, loss 0.04927, detection recall 0.3808, detection precision 0.8085, correction recall 0.7249, correction precision 0.8833
# Epoch 0, Step 5720/8882, Total Step 5720, loss 0.05044, detection recall 0.3735, detection precision 0.7674, correction recall 0.7312, correction precision 0.8870
# Epoch 0, Step 5740/8882, Total Step 5740, loss 0.05434, detection recall 0.3699, detection precision 0.7877, correction recall 0.7143, correction precision 0.8532
# Epoch 0, Step 5760/8882, Total Step 5760, loss 0.04542, detection recall 0.4104, detection precision 0.7948, correction recall 0.7351, correction precision 0.8907
# Epoch 0, Step 5780/8882, Total Step 5780, loss 0.04842, detection recall 0.4195, detection precision 0.8289, correction recall 0.7181, correction precision 0.8743
# Epoch 0, Step 5800/8882, Total Step 5800, loss 0.04854, detection recall 0.4174, detection precision 0.8220, correction recall 0.7187, correction precision 0.8822
# Epoch 0, Step 5820/8882, Total Step 5820, loss 0.05311, detection recall 0.3673, detection precision 0.7754, correction recall 0.7312, correction precision 0.9007
# Epoch 0, Step 5840/8882, Total Step 5840, loss 0.05330, detection recall 0.4084, detection precision 0.8315, correction recall 0.7086, correction precision 0.8867
# Epoch 0, Step 5860/8882, Total Step 5860, loss 0.05339, detection recall 0.3771, detection precision 0.8208, correction recall 0.7164, correction precision 0.8871
# Epoch 0, Step 5880/8882, Total Step 5880, loss 0.04991, detection recall 0.4355, detection precision 0.7984, correction recall 0.7385, correction precision 0.8989
# Epoch 0, Step 5900/8882, Total Step 5900, loss 0.05831, detection recall 0.3618, detection precision 0.8175, correction recall 0.6985, correction precision 0.8911
# ...
# Epoch 4, Step 8132/8882, Total Step 43660, loss 0.00689, detection recall 0.6897, detection precision 0.9088, correction recall 0.9732, correction precision 0.9842
# Epoch 4, Step 8152/8882, Total Step 43680, loss 0.00563, detection recall 0.6938, detection precision 0.8949, correction recall 0.9758, correction precision 0.9855
# Epoch 4, Step 8172/8882, Total Step 43700, loss 0.00657, detection recall 0.6945, detection precision 0.8837, correction recall 0.9688, correction precision 0.9786
# Epoch 4, Step 8192/8882, Total Step 43720, loss 0.00566, detection recall 0.6555, detection precision 0.8869, correction recall 0.9766, correction precision 0.9854
# Epoch 4, Step 8212/8882, Total Step 43740, loss 0.00652, detection recall 0.6725, detection precision 0.8882, correction recall 0.9703, correction precision 0.9833
# Epoch 4, Step 8232/8882, Total Step 43760, loss 0.00658, detection recall 0.6425, detection precision 0.8632, correction recall 0.9718, correction precision 0.9825
# Epoch 4, Step 8252/8882, Total Step 43780, loss 0.00712, detection recall 0.6741, detection precision 0.9028, correction recall 0.9632, correction precision 0.9785
# Epoch 4, Step 8272/8882, Total Step 43800, loss 0.00647, detection recall 0.6670, detection precision 0.8877, correction recall 0.9685, correction precision 0.9784
# Epoch 4, Step 8292/8882, Total Step 43820, loss 0.00717, detection recall 0.6889, detection precision 0.8904, correction recall 0.9695, correction precision 0.9817
# Epoch 4, Step 8312/8882, Total Step 43840, loss 0.00461, detection recall 0.6717, detection precision 0.8955, correction recall 0.9816, correction precision 0.9884
# Epoch 4, Step 8332/8882, Total Step 43860, loss 0.00683, detection recall 0.6932, detection precision 0.8845, correction recall 0.9691, correction precision 0.9876
# Epoch 4, Step 8352/8882, Total Step 43880, loss 0.00812, detection recall 0.6737, detection precision 0.9049, correction recall 0.9580, correction precision 0.9841
# Epoch 4, Step 8372/8882, Total Step 43900, loss 0.00712, detection recall 0.6733, detection precision 0.8786, correction recall 0.9767, correction precision 0.9811
# Epoch 4, Step 8392/8882, Total Step 43920, loss 0.00669, detection recall 0.6586, detection precision 0.8850, correction recall 0.9649, correction precision 0.9843
# Epoch 4, Step 8412/8882, Total Step 43940, loss 0.00635, detection recall 0.6773, detection precision 0.8955, correction recall 0.9682, correction precision 0.9800
# Epoch 4, Step 8432/8882, Total Step 43960, loss 0.00837, detection recall 0.6598, detection precision 0.8707, correction recall 0.9602, correction precision 0.9770
# Epoch 4, Step 8452/8882, Total Step 43980, loss 0.00719, detection recall 0.6561, detection precision 0.8900, correction recall 0.9650, correction precision 0.9822
# Epoch 4, Step 8472/8882, Total Step 44000, loss 0.00837, detection recall 0.6579, detection precision 0.8499, correction recall 0.9539, correction precision 0.9797
# Epoch 4, Step 8492/8882, Total Step 44020, loss 0.00706, detection recall 0.6560, detection precision 0.8828, correction recall 0.9669, correction precision 0.9832
# Epoch 4, Step 8512/8882, Total Step 44040, loss 0.00612, detection recall 0.6537, detection precision 0.8910, correction recall 0.9726, correction precision 0.9804
# Epoch 4, Step 8532/8882, Total Step 44060, loss 0.00687, detection recall 0.6815, detection precision 0.8951, correction recall 0.9623, correction precision 0.9825
# Epoch 4, Step 8552/8882, Total Step 44080, loss 0.00672, detection recall 0.6806, detection precision 0.8739, correction recall 0.9729, correction precision 0.9829
# Epoch 4, Step 8572/8882, Total Step 44100, loss 0.00608, detection recall 0.6607, detection precision 0.8919, correction recall 0.9684, correction precision 0.9817
# Epoch 4, Step 8592/8882, Total Step 44120, loss 0.00727, detection recall 0.6909, detection precision 0.8662, correction recall 0.9538, correction precision 0.9775
# Epoch 4, Step 8612/8882, Total Step 44140, loss 0.00671, detection recall 0.6692, detection precision 0.8793, correction recall 0.9708, correction precision 0.9846
# Epoch 4, Step 8632/8882, Total Step 44160, loss 0.00716, detection recall 0.6783, detection precision 0.9038, correction recall 0.9650, correction precision 0.9794
# Epoch 4, Step 8652/8882, Total Step 44180, loss 0.00713, detection recall 0.6644, detection precision 0.8716, correction recall 0.9625, correction precision 0.9735
# Epoch 4, Step 8672/8882, Total Step 44200, loss 0.00798, detection recall 0.6819, detection precision 0.8581, correction recall 0.9542, correction precision 0.9771
# Epoch 4, Step 8692/8882, Total Step 44220, loss 0.00684, detection recall 0.6659, detection precision 0.8671, correction recall 0.9667, correction precision 0.9809
# Epoch 4, Step 8712/8882, Total Step 44240, loss 0.00720, detection recall 0.6483, detection precision 0.8956, correction recall 0.9583, correction precision 0.9748
# Epoch 4, Step 8732/8882, Total Step 44260, loss 0.00577, detection recall 0.7072, detection precision 0.9032, correction recall 0.9747, correction precision 0.9884
# Epoch 4, Step 8752/8882, Total Step 44280, loss 0.00618, detection recall 0.6570, detection precision 0.8997, correction recall 0.9678, correction precision 0.9853
# Epoch 4, Step 8772/8882, Total Step 44300, loss 0.00785, detection recall 0.6633, detection precision 0.8935, correction recall 0.9582, correction precision 0.9803
# Epoch 4, Step 8792/8882, Total Step 44320, loss 0.00619, detection recall 0.6882, detection precision 0.8692, correction recall 0.9722, correction precision 0.9853
# Epoch 4, Step 8812/8882, Total Step 44340, loss 0.00675, detection recall 0.6853, detection precision 0.8924, correction recall 0.9643, correction precision 0.9752
# Epoch 4, Step 8832/8882, Total Step 44360, loss 0.00660, detection recall 0.6567, detection precision 0.9023, correction recall 0.9611, correction precision 0.9774
# Epoch 4, Step 8852/8882, Total Step 44380, loss 0.00761, detection recall 0.6907, detection precision 0.8913, correction recall 0.9557, correction precision 0.9807
# Epoch 4, Step 8872/8882, Total Step 44400, loss 0.00666, detection recall 0.6617, detection precision 0.9013, correction recall 0.9643, correction precision 0.9767
# Epoch 5, Step 10/8882, Total Step 44420, loss 0.00532, detection recall 0.7065, detection precision 0.8728, correction recall 0.9834, correction precision 0.9881
# Epoch 5, Step 30/8882, Total Step 44440, loss 0.00544, detection recall 0.6799, detection precision 0.9032, correction recall 0.9779, correction precision 0.9922
# Epoch 5, Step 50/8882, Total Step 44460, loss 0.00442, detection recall 0.6758, detection precision 0.8980, correction recall 0.9840, correction precision 0.9908
# Epoch 5, Step 70/8882, Total Step 44480, loss 0.00508, detection recall 0.6659, detection precision 0.8853, correction recall 0.9836, correction precision 0.9923
# Epoch 5, Step 90/8882, Total Step 44500, loss 0.00378, detection recall 0.6711, detection precision 0.8958, correction recall 0.9911, correction precision 0.9944
# Epoch 5, Step 110/8882, Total Step 44520, loss 0.00449, detection recall 0.6751, detection precision 0.8899, correction recall 0.9805, correction precision 0.9908
# Epoch 5, Step 130/8882, Total Step 44540, loss 0.00472, detection recall 0.6844, detection precision 0.8976, correction recall 0.9826, correction precision 0.9923
# Epoch 5, Step 150/8882, Total Step 44560, loss 0.00470, detection recall 0.6768, detection precision 0.8943, correction recall 0.9786, correction precision 0.9943
# Epoch 5, Step 170/8882, Total Step 44580, loss 0.00422, detection recall 0.7277, detection precision 0.8959, correction recall 0.9826, correction precision 0.9895
# Epoch 5, Step 190/8882, Total Step 44600, loss 0.00429, detection recall 0.6800, detection precision 0.8824, correction recall 0.9805, correction precision 0.9884
# Epoch 5, Step 210/8882, Total Step 44620, loss 0.00375, detection recall 0.7260, detection precision 0.8866, correction recall 0.9922, correction precision 0.9955
# Epoch 5, Step 230/8882, Total Step 44640, loss 0.00460, detection recall 0.6623, detection precision 0.8798, correction recall 0.9823, correction precision 0.9933
# Epoch 5, Step 250/8882, Total Step 44660, loss 0.00355, detection recall 0.7132, detection precision 0.9032, correction recall 0.9900, correction precision 0.9933
# Epoch 5, Step 270/8882, Total Step 44680, loss 0.00408, detection recall 0.7228, detection precision 0.8834, correction recall 0.9888, correction precision 0.9955
# Epoch 5, Step 290/8882, Total Step 44700, loss 0.00421, detection recall 0.6577, detection precision 0.8980, correction recall 0.9844, correction precision 0.9910
# Epoch 5, Step 310/8882, Total Step 44720, loss 0.00470, detection recall 0.6972, detection precision 0.8916, correction recall 0.9808, correction precision 0.9909
# Epoch 5, Step 330/8882, Total Step 44740, loss 0.00425, detection recall 0.6905, detection precision 0.8826, correction recall 0.9841, correction precision 0.9954
# Epoch 5, Step 350/8882, Total Step 44760, loss 0.00460, detection recall 0.6645, detection precision 0.8873, correction recall 0.9781, correction precision 0.9911
# Epoch 5, Step 370/8882, Total Step 44780, loss 0.00425, detection recall 0.7135, detection precision 0.8881, correction recall 0.9876, correction precision 0.9943
# Epoch 5, Step 390/8882, Total Step 44800, loss 0.00488, detection recall 0.6872, detection precision 0.8914, correction recall 0.9725, correction precision 0.9888
# Epoch 5, Step 410/8882, Total Step 44820, loss 0.00436, detection recall 0.6895, detection precision 0.8952, correction recall 0.9877, correction precision 0.9921
# Epoch 5, Step 430/8882, Total Step 44840, loss 0.00534, detection recall 0.6610, detection precision 0.8683, correction recall 0.9741, correction precision 0.9830
# Epoch 5, Step 450/8882, Total Step 44860, loss 0.00403, detection recall 0.6720, detection precision 0.8976, correction recall 0.9904, correction precision 0.9925
# Epoch 5, Step 470/8882, Total Step 44880, loss 0.00373, detection recall 0.6910, detection precision 0.9004, correction recall 0.9876, correction precision 0.9921
# Epoch 5, Step 490/8882, Total Step 44900, loss 0.00467, detection recall 0.6780, detection precision 0.8730, correction recall 0.9830, correction precision 0.9920
# Epoch 5, Step 510/8882, Total Step 44920, loss 0.00435, detection recall 0.6770, detection precision 0.8831, correction recall 0.9823, correction precision 0.9889
# Epoch 5, Step 530/8882, Total Step 44940, loss 0.00450, detection recall 0.6889, detection precision 0.8960, correction recall 0.9811, correction precision 0.9944
# Epoch 5, Step 550/8882, Total Step 44960, loss 0.00383, detection recall 0.6847, detection precision 0.9170, correction recall 0.9967, correction precision 0.9934
# Epoch 5, Step 570/8882, Total Step 44980, loss 0.00487, detection recall 0.7011, detection precision 0.8909, correction recall 0.9772, correction precision 0.9857
# Epoch 5, Step 590/8882, Total Step 45000, loss 0.00457, detection recall 0.6814, detection precision 0.8931, correction recall 0.9879, correction precision 0.9945
# Epoch 5, Step 610/8882, Total Step 45020, loss 0.00427, detection recall 0.6867, detection precision 0.8834, correction recall 0.9825, correction precision 0.9901
# Epoch 5, Step 630/8882, Total Step 45040, loss 0.00376, detection recall 0.6912, detection precision 0.9011, correction recall 0.9890, correction precision 0.9923
# Epoch 5, Step 650/8882, Total Step 45060, loss 0.00429, detection recall 0.6764, detection precision 0.8942, correction recall 0.9865, correction precision 0.9977
# Epoch 5, Step 670/8882, Total Step 45080, loss 0.00397, detection recall 0.7135, detection precision 0.8939, correction recall 0.9866, correction precision 0.9933
# Epoch 5, Step 690/8882, Total Step 45100, loss 0.00353, detection recall 0.6972, detection precision 0.9244, correction recall 0.9888, correction precision 0.9977
# Epoch 5, Step 710/8882, Total Step 45120, loss 0.00385, detection recall 0.6886, detection precision 0.8858, correction recall 0.9942, correction precision 0.9919
# Epoch 5, Step 730/8882, Total Step 45140, loss 0.00466, detection recall 0.6946, detection precision 0.8771, correction recall 0.9776, correction precision 0.9898
# Epoch 5, Step 750/8882, Total Step 45160, loss 0.00420, detection recall 0.6876, detection precision 0.9082, correction recall 0.9812, correction precision 0.9955
# Epoch 5, Step 770/8882, Total Step 45180, loss 0.00419, detection recall 0.7046, detection precision 0.8897, correction recall 0.9878, correction precision 0.9878
# Epoch 5, Step 790/8882, Total Step 45200, loss 0.00404, detection recall 0.7148, detection precision 0.8822, correction recall 0.9845, correction precision 0.9922
# Epoch 5, Step 810/8882, Total Step 45220, loss 0.00577, detection recall 0.6461, detection precision 0.8505, correction recall 0.9813, correction precision 0.9878
# Epoch 5, Step 830/8882, Total Step 45240, loss 0.00411, detection recall 0.6962, detection precision 0.9023, correction recall 0.9856, correction precision 0.9944
# Epoch 5, Step 850/8882, Total Step 45260, loss 0.00407, detection recall 0.6830, detection precision 0.8825, correction recall 0.9872, correction precision 0.9941
# Epoch 5, Step 870/8882, Total Step 45280, loss 0.00449, detection recall 0.6776, detection precision 0.8911, correction recall 0.9826, correction precision 0.9945
# Epoch 5, Step 890/8882, Total Step 45300, loss 0.00402, detection recall 0.6962, detection precision 0.8834, correction recall 0.9827, correction precision 0.9913
# Epoch 5, Step 910/8882, Total Step 45320, loss 0.00452, detection recall 0.6959, detection precision 0.8601, correction recall 0.9845, correction precision 0.9933
# Epoch 5, Step 930/8882, Total Step 45340, loss 0.00372, detection recall 0.6738, detection precision 0.8767, correction recall 0.9932, correction precision 0.9955
# Epoch 5, Step 950/8882, Total Step 45360, loss 0.00366, detection recall 0.6891, detection precision 0.8840, correction recall 0.9934, correction precision 0.9967
# Epoch 5, Step 970/8882, Total Step 45380, loss 0.00379, detection recall 0.6820, detection precision 0.8664, correction recall 0.9917, correction precision 0.9882
# Epoch 5, Step 990/8882, Total Step 45400, loss 0.00490, detection recall 0.6568, detection precision 0.8809, correction recall 0.9814, correction precision 0.9900
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_60675/3585074924.py in <module>
#      19         correction_outputs, detection_outputs = model(sequences)
#      20         loss = criterion(correction_outputs, correction_targets, detection_outputs, detection_targets)
# ---> 21         loss.backward()
#      22         optimizer.step()
#      23         optimizer.zero_grad()
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     394                 create_graph=create_graph,
#     395                 inputs=inputs)
# --> 396         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     397
#     398     def register_hook(self, hook):
#
# ~/Programs/anaconda3/lib/python3.9/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     171     # some Python versions print out the first line of a multi-line function
#     172     # calls in the traceback and some print out the last line
# --> 173     Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     174         tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     175         allow_unreachable=True, accumulate_grad=True)  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %% [markdown]
# # 模型评估

# %% [markdown]
# 模型评估使用了SIGHAN 2013,2014,2015三个数据集对模型进行评估。对于Detection的Precision和Recall的评估，使用的是Correction Network的结果，这和训练阶段有所不同，这是因为Detection Network只是帮助Correction Network训练的，其结果在使用时不具备参考价值。

# %%
model = model.eval()

# %%
def evaluation(test_data):
    d_recall_numerator = 0  # Detection的Recall的分子
    d_recall_denominator = 0  # Detection的Recall的分母
    d_precision_numerator = 0  # Detection的precision的分子
    d_precision_denominator = 0  # Detection的precision的分母
    c_recall_numerator = 0  # Correction的Recall的分子
    c_recall_denominator = 0  # Correction的Recall的分母
    c_precision_numerator = 0  # Correction的precision的分子
    c_precision_denominator = 0  # Correction的precision的分母

    prograss = tqdm(range(len(test_data)))
    for i in prograss:
        src, tgt = test_data[i]['src'], test_data[i]['tgt']

        src_tokens = tokenizer(src, return_tensors='pt', max_length=128, truncation=True)['input_ids'][0][1:-1]
        tgt_tokens = tokenizer(tgt, return_tensors='pt', max_length=128, truncation=True)['input_ids'][0][1:-1]

        # 正常情况下，src和tgt的长度应该是一致的
        if len(src_tokens) != len(tgt_tokens):
            print("第%d条数据异常" % i)
            continue

        correction_outputs, _ = model(src)
        predict_tokens = correction_outputs[0][1:len(src_tokens) + 1].argmax(1).detach().cpu()

        # 计算错误token的数量
        d_recall_denominator += (src_tokens != tgt_tokens).sum().item()
        # 计算在这些错误token，有多少网络也认为它是错误的
        d_recall_numerator += (predict_tokens != src_tokens)[src_tokens != tgt_tokens].sum().item()
        # 计算网络找出的错误token的数量
        d_precision_denominator += (predict_tokens != src_tokens).sum().item()
        # 计算在网络找出的这些错误token中，有多少是真正错误的
        d_precision_numerator += (src_tokens != tgt_tokens)[predict_tokens != src_tokens].sum().item()
        # 计算Detection的recall、precision和f1-score
        d_recall = d_recall_numerator / (d_recall_denominator + 1e-9)
        d_precision = d_precision_numerator / (d_precision_denominator + 1e-9)
        d_f1_score = 2 * (d_recall * d_precision) / (d_recall + d_precision + 1e-9)

        # 计算错误token的数量
        c_recall_denominator += (src_tokens != tgt_tokens).sum().item()
        # 计算在这些错误token中，有多少网络预测对了
        c_recall_numerator += (predict_tokens == tgt_tokens)[src_tokens != tgt_tokens].sum().item()
        # 计算网络找出的错误token的数量
        c_precision_denominator += (predict_tokens != src_tokens).sum().item()
        # 计算网络找出的错误token中，有多少是正确修正的
        c_precision_numerator += (predict_tokens == tgt_tokens)[predict_tokens != src_tokens].sum().item()

        # 计算Correction的recall、precision和f1-score
        c_recall = c_recall_numerator / (c_recall_denominator + 1e-9)
        c_precision = c_precision_numerator / (c_precision_denominator + 1e-9)
        c_f1_score = 2 * (c_recall * c_precision) / (c_recall + c_precision + 1e-9)

        prograss.set_postfix({
            'd_recall': d_recall,
            'd_precision': d_precision,
            'd_f1_score': d_f1_score,
            'c_recall': c_recall,
            'c_precision': c_precision,
            'c_f1_score': c_f1_score,
        })

# %%
with open("data/test.sighan13.pkl", mode='br') as f:
    sighan13 = pickle.load(f)
evaluation(sighan13)
# Out:
# 100%|██████████| 1000/1000 [00:11<00:00, 86.81it/s, d_recall=0.885, d_precision=0.754, d_f1_score=0.814, c_recall=0.876, c_precision=0.746, c_f1_score=0.806]

# %%
with open("data/test.sighan14.pkl", mode='br') as f:
    sighan14 = pickle.load(f)
evaluation(sighan14)
# Out:
# 100%|██████████| 1062/1062 [00:13<00:00, 78.91it/s, d_recall=0.76, d_precision=0.787, d_f1_score=0.773, c_recall=0.747, c_precision=0.773, c_f1_score=0.76]

# %%
with open("data/test.sighan15.pkl", mode='br') as f:
    sighan15 = pickle.load(f)
evaluation(sighan15)
# Out:
# 100%|██████████| 1100/1100 [00:13<00:00, 80.68it/s, d_recall=0.845, d_precision=0.839, d_f1_score=0.842, c_recall=0.817, c_precision=0.811, c_f1_score=0.814]

# %% [markdown]
# # 模型使用

# %% [markdown]
# 最后，我们来真正的使用一下该模型，看下效果：

# %%
def predict(text):
    sequences = [text]
    correction_outputs, _ = model(sequences)
    tokens = correction_outputs[0][1:len(text) + 1].argmax(1)
    return ''.join(tokenizer.convert_ids_to_tokens(tokens))

# %%
predict("今天早上我吃了以个火聋果")
# Out:
# '今天早上我吃了一个火聋果'

# %%
predict("我是联系时长两年半的个人练习生蔡徐鲲，喜欢唱跳RAP蓝球")
# Out:
# '我是联系时长两年半的个人练习生蔡许鲲，喜欢唱跳ra##p蓝球。[SEP]'

# %%
predict('大明恨高兴他渴了很多埤酒')
# Out:
# '大明很高兴他渴了很多啤酒'

# %% [markdown]
# 虽然在数据上模型表现还不错，但在真正使用场景上，效果还是不够好。中文文本纠错果然是一个比较难的任务 T_T !

# %% [markdown]
# # 参考文献
#
# [MDCSpell论文](https://aclanthology.org/2022.findings-acl.98/): https://aclanthology.org/2022.findings-acl.98/
#
# [MDCSpell论文笔记](https://blog.csdn.net/zhaohongfei_358/article/details/126973451)：https://blog.csdn.net/zhaohongfei_358/article/details/126973451
